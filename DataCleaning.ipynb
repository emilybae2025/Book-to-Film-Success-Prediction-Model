# %%
import pandas as pd
df = pd.read_csv("book_adaptation_df_clean.csv")
df
# Out:
#                        movie_title    imdb_id  movie_budget  movie_revenue  \
# 0                        Toy Story  tt0114709  6.465807e+07   8.051095e+08
# 1                          Jumanji  tt0113497  1.400925e+08   5.663988e+08
# 2                 Grumpier Old Men  tt0113228  0.000000e+00   0.000000e+00
# 3                Waiting to Exhale  tt0114885  3.448431e+07   1.755513e+08
# 4      Father of the Bride Part II  tt0113041  0.000000e+00   1.650482e+08
# ...                            ...        ...           ...            ...
# 45461                       Subdue  tt6209470  0.000000e+00   0.000000e+00
# 45462          Century of Birthing  tt2028550  0.000000e+00   0.000000e+00
# 45463                     Betrayal  tt0303758  0.000000e+00   0.000000e+00
# 45464             Satan Triumphant  tt0008536  0.000000e+00   0.000000e+00
# 45465                     Queerama  tt6980792  0.000000e+00   0.000000e+00
#
# ...

# %%
df_hasData = df[df["imdb_rating"] != 0]
df_hasData
# Out:
#                        movie_title    imdb_id  movie_budget  movie_revenue  \
# 0                        Toy Story  tt0114709  6.465807e+07   8.051095e+08
# 1                          Jumanji  tt0113497  1.400925e+08   5.663988e+08
# 2                 Grumpier Old Men  tt0113228  0.000000e+00   0.000000e+00
# 3                Waiting to Exhale  tt0114885  3.448431e+07   1.755513e+08
# 4      Father of the Bride Part II  tt0113041  0.000000e+00   1.650482e+08
# ...                            ...        ...           ...            ...
# 45461                       Subdue  tt6209470  0.000000e+00   0.000000e+00
# 45462          Century of Birthing  tt2028550  0.000000e+00   0.000000e+00
# 45463                     Betrayal  tt0303758  0.000000e+00   0.000000e+00
# 45464             Satan Triumphant  tt0008536  0.000000e+00   0.000000e+00
# 45465                     Queerama  tt6980792  0.000000e+00   0.000000e+00
#
# ...
